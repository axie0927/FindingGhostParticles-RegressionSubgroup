# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
##########################################################################
# Important Note: This notebook only uses one csv file to test the model #
##########################################################################

# %%
# assign processed data to data_files
cwd = os.getcwd()
data_dir = os.path.join(cwd, "data/")
data_files = [f for f in os.listdir(str(data_dir)) if f.endswith('csv')]

data = pd.read_csv(os.path.join(data_dir,data_files[0]))
data
# Out:
#              id   tdrift  tdrift50  tdrift10       rea           dcr  \
# 0        650000   75.924      38.0       7.6  0.306251  5.647056e+05
# 1        650001   82.917      41.5       8.3  0.610983  5.467540e+05
# 2        650002  115.884      58.0      11.6  1.585428  2.801101e+05
# 3        650003  128.871      64.5      12.9 -0.471883  8.859788e+04
# 4        650004   95.904      48.0       9.6  0.903343  1.759048e+06
# ...         ...      ...       ...       ...       ...           ...
# 1689996  649995  103.896      52.0      10.4  1.386256  2.888775e+05
# 1689997  649996   44.955      22.5       4.5 -0.555437  8.694774e+05
# 1689998  649997  165.834      83.0      16.6  1.516233  2.478339e+05
# 1689999  649998   95.904      48.0       9.6  0.647120  3.457733e+06
# 1690000  649999   99.900      50.0      10.0  1.168612  4.058758e+05
#
#          peakindex  peakvalue  tailslope  currentamp      lfpr      lq80  \
# 0             1040     1236.0  -0.107739    0.006022  0.016692  137120.0
# 1             1049     1341.0  -0.110221    0.003851  0.018183  214469.0
# 2             1052      775.0  -0.056455    0.005939  0.023463  188754.0
# 3             1068      242.0  -0.012898    0.004452  0.010622  109347.0
# 4             1060     3802.0  -0.358300    0.006815  0.019583  203822.0
# ...            ...        ...        ...         ...       ...       ...
# 1689996       1037      657.0  -0.055199    0.006327  0.021953   78290.0
# 1689997       1023     1930.0  -0.169472    0.007386  0.017672  185348.0
# 1689998       1066      676.0  -0.050436    0.004362  0.024428  171916.0
# 1689999       1073     6729.0  -0.701681    0.005781  0.018728  348388.0
# 1690000       1042      930.0  -0.081339    0.007037  0.022219   94534.0
#
#          areagrowthrate  inflection point  risingedgeslope  energylabel  \
# 0             -525788.0               332        20.697813   449.096599
# 1             -536552.0               337        17.853155   472.905768
# 2             -268393.5               337         4.624622   240.859403
# 3              -64318.0               360         1.477667    56.433683
# 4            -1714558.5               288        46.383844  1512.367517
# ...                 ...               ...              ...          ...
# 1689996       -265790.5               308         5.563203   238.264153
# 1689997       -848319.5               271        50.753887   727.778128
# 1689998       -217168.0               300         2.899391   206.356597
# 1689999      -3073543.0               342        85.845334  2615.179984
# 1690000       -390369.5               252         9.351527   341.602948
#
#          highavse  lowavse  truedcr     lq
# 0            True     True     True   True
# 1            True     True     True   True
# 2            True     True     True   True
# 3            True     True     True   True
# 4            True     True     True   True
# ...           ...      ...      ...    ...
# 1689996      True     True     True   True
# 1689997     False    False     True  False
# 1689998      True     True     True   True
# 1689999      True     True     True   True
# 1690000      True     True     True   True
#
# [1690001 rows x 20 columns]

# %%
# Drop columns needed for classification group
boolean_col = ['highavse','lowavse','truedcr','lq']
data_filtered = data.drop(columns=boolean_col+['id'])


# Find and Drop rows with missing values
data_filtered = data_filtered.dropna()


# Drop irrelevant features and feature with multicollinearity 
data_filtered = data_filtered.drop(columns=['tdrift50','tdrift10'])
X = data_filtered.drop(columns=['energylabel'])
y = data_filtered['energylabel']

# %%
# Train test split + standardization
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)
scaler = StandardScaler()
X_train_standardized = scaler.fit_transform(X_train)
X_test_standardized = scaler.transform(X_test)

# GridCV to find best lambda
alpha_range = np.logspace(-5, 2.5, 100)
param_grid = {"alpha": alpha_range}
ridge = Ridge()
grid_search = GridSearchCV(estimator=ridge, param_grid={"alpha": alpha_range}, cv=5, scoring='neg_mean_squared_error')

# Fit the model
grid_search.fit(X_train_standardized, y_train)

best_alpha = grid_search.best_params_['alpha']
print(f"lambda: {best_alpha}")

# Train the Ridge Regression model with the best alpha
ridge_reg = Ridge(alpha=best_alpha)
ridge_reg.fit(X_train_standardized,y_train)
y_pred = ridge_reg.predict(X_test_standardized)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2= r2_score(y_test, y_pred)
# Out:
# lambda: 1e-05

# %%
mse,r2
# Out:
# (4904.623324733912, 0.9890781350334877)

# %%
np.mean(abs(y_pred - y_test))
# Out:
# 16.361993487043588

# %%
data_filtered.corr()
# Out:
#                     tdrift       rea       dcr  peakindex  peakvalue  \
# tdrift            1.000000 -0.353646 -0.119906   0.966816  -0.104132
# rea              -0.353646  1.000000  0.028737  -0.431403   0.029845
# dcr              -0.119906  0.028737  1.000000   0.027008   0.997981
# peakindex         0.966816 -0.431403  0.027008   1.000000   0.042621
# peakvalue        -0.104132  0.029845  0.997981   0.042621   1.000000
# tailslope         0.112163 -0.025223 -0.996803  -0.033552  -0.996964
# currentamp       -0.129910  0.245087  0.213819  -0.106819   0.198594
# lfpr             -0.287289  0.649042  0.089385  -0.278013   0.091994
# lq80              0.200410 -0.261714  0.684834   0.317134   0.711452
# areagrowthrate    0.119038 -0.038562 -0.998767  -0.027973  -0.999103
# inflection point  0.131842 -0.289455 -0.040027   0.147367  -0.045428
# risingedgeslope  -0.207463 -0.069715  0.917027  -0.058978   0.905183
# energylabel      -0.104336  0.028187  0.992463   0.042785   0.994342
#
#                   tailslope  currentamp      lfpr      lq80  areagrowthrate  \
# tdrift             0.112163   -0.129910 -0.287289  0.200410        0.119038
# rea               -0.025223    0.245087  0.649042 -0.261714       -0.038562
# dcr               -0.996803    0.213819  0.089385  0.684834       -0.998767
# peakindex         -0.033552   -0.106819 -0.278013  0.317134       -0.027973
# peakvalue         -0.996964    0.198594  0.091994  0.711452       -0.999103
# tailslope          1.000000   -0.201432 -0.087800 -0.704431        0.996307
# currentamp        -0.201432    1.000000  0.093334 -0.110651       -0.214353
# lfpr              -0.087800    0.093334  1.000000 -0.078781       -0.094215
# lq80              -0.704431   -0.110651 -0.078781  1.000000       -0.683208
# areagrowthrate     0.996307   -0.214353 -0.094215 -0.683208        1.000000
# inflection point   0.038370   -0.026070 -0.240215  0.038102        0.046493
# risingedgeslope   -0.902061    0.244163  0.024977  0.554716       -0.913401
# energylabel       -0.991746    0.202547  0.092354  0.696343       -0.994058
#
#                   inflection point  risingedgeslope  energylabel
# tdrift                    0.131842        -0.207463    -0.104336
# rea                      -0.289455        -0.069715     0.028187
# dcr                      -0.040027         0.917027     0.992463
# peakindex                 0.147367        -0.058978     0.042785
# peakvalue                -0.045428         0.905183     0.994342
# tailslope                 0.038370        -0.902061    -0.991746
# currentamp               -0.026070         0.244163     0.202547
# lfpr                     -0.240215         0.024977     0.092354
# lq80                      0.038102         0.554716     0.696343
# areagrowthrate            0.046493        -0.913401    -0.994058
# inflection point          1.000000        -0.026385    -0.040300
# risingedgeslope          -0.026385         1.000000     0.899816
# energylabel              -0.040300         0.899816     1.000000

# %%
X_train
# Out:
#           tdrift       rea           dcr  peakindex  peakvalue  tailslope  \
# 305058   116.883  0.609233  543485.40625       1070     1209.0  -0.106624
# 637456    97.902  0.621089  275333.50000       1057      674.0  -0.054388
# 133917    85.914  0.954826  301019.25000       1034      694.0  -0.056668
# 1041655  117.882  1.119602  407047.71875       1061      892.0  -0.080081
# 274326   110.889 -0.157120  557659.71875       1067     1197.0  -0.106893
# ...          ...       ...           ...        ...        ...        ...
# 14370     64.935  0.499625  265744.68750       1018      625.0  -0.048555
# 292682   209.790 -0.785466  241984.37500       1151      563.0  -0.041015
# 183641    72.927  0.127937  614589.84375       1042     1349.0  -0.119925
# 849596    97.902  1.050445  159639.59375       1031      411.0  -0.028415
# 479976    84.915  0.874890  264753.50000       1038      729.0  -0.050548
#
#          currentamp      lfpr      lq80  areagrowthrate  inflection point  \
# 305058     0.006071  0.021196  123293.0       -514048.0               304
# 637456     0.003855  0.017666  115033.0       -264010.5               298
# 133917     0.005541  0.021488  111789.0       -272781.0               342
# 1041655    0.004780  0.021254   77162.0       -378864.0               286
# 274326     0.004438  0.020023  126866.0       -508111.5               380
# ...             ...       ...       ...             ...               ...
# 14370      0.005932  0.018987  112919.0       -240992.0               361
# 292682     0.004920  0.015914  192199.0       -177678.0               345
# 183641     0.006110  0.018323  145372.0       -578553.0               318
# 849596     0.005574  0.016779  107261.0       -138976.0               386
# 479976     0.004424  0.016215  191769.0       -250672.0               335
#
#          risingedgeslope
# 305058         12.729758
# 637456          7.462171
# 133917          7.995679
# 1041655         7.815813
# 274326         14.499245
# ...                  ...
# 14370          10.656818
# 292682          2.519041
# 183641         23.982229
# 849596          3.548273
# 479976          7.732851
#
# [1182975 rows x 12 columns]
